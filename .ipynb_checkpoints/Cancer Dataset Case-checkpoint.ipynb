# %%
from sklearn.datasets import load_breast_cancer
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Import Data

# %%
# Load Data
breast = load_breast_cancer()

# %%
# Convert to dataframe
X = pd.DataFrame(breast.data)
Y = pd.DataFrame(breast.target)
kolom = list(breast.feature_names) + ['Y']

# %%
# Set column names
breast_data = pd.concat([X,Y],axis=1)
breast_data.columns = kolom

# %%
"""
Kita perlu melakukan reduksi dimensi karena terdapat 569 variable yang notabene membenani komputasi dan
menyebabkan model kompleks
"""
breast_data.columns
print(len(breast_data))
# Out:
# 569

# %%
breast_data
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %% [markdown]
# # 2. Standardize

# %%
from sklearn.preprocessing import StandardScaler
x = breast_data.loc[:, breast.feature_names].values
x = StandardScaler().fit_transform(x) # normalizing the features

# %%
x.shape
# Out:
# (569, 30)

# %%
col = ['feature'+str(k) for k in range(x.shape[1])]
df_x = pd.DataFrame(x,columns=col)

# %%
df_x.head()
# Out:
#    feature0  feature1  feature2  feature3  feature4  feature5  feature6  \
# 0  1.097064 -2.073335  1.269934  0.984375  1.568466  3.283515  2.652874
# 1  1.829821 -0.353632  1.685955  1.908708 -0.826962 -0.487072 -0.023846
# 2  1.579888  0.456187  1.566503  1.558884  0.942210  1.052926  1.363478
# 3 -0.768909  0.253732 -0.592687 -0.764464  3.283553  3.402909  1.915897
# 4  1.750297 -1.151816  1.776573  1.826229  0.280372  0.539340  1.371011
#
#    feature7  feature8  feature9  ...  feature20  feature21  feature22  \
# 0  2.532475  2.217515  2.255747  ...   1.886690  -1.359293   2.303601
# 1  0.548144  0.001392 -0.868652  ...   1.805927  -0.369203   1.535126
# 2  2.037231  0.939685 -0.398008  ...   1.511870  -0.023974   1.347475
# 3  1.451707  2.867383  4.910919  ...  -0.281464   0.133984  -0.249939
# 4  1.428493 -0.009560 -0.562450  ...   1.298575  -1.466770   1.338539
#
#    feature23  feature24  feature25  feature26  feature27  feature28  feature29
# ...

# %% [markdown]
# # 3. PCA

# %%
from sklearn.decomposition import PCA
pca_breast = PCA(n_components=2)
principalComponents_breast = pca_breast.fit_transform(x)

# %%
"""
Komponen PC1 mampu menyerap 44% dari data, sedangkan PC2 mampu menyerap 19% dari data.
"""
pca_breast.explained_variance_ratio_
# Out:
# array([0.44272026, 0.18971182])

# %%
dfPC =pd.DataFrame(principalComponents_breast,columns=['PC1','PC2'])
dfPCFull = pd.concat([df_principalComponents_breast,breast_data['Y']],axis=1)

# %%
dfPCFull
# Out:
#            PC1        PC2
# 0     9.192837   1.948583
# 1     2.387802  -3.768172
# 2     5.733896  -1.075174
# 3     7.122953  10.275589
# 4     3.935302  -1.948072
# ..         ...        ...
# 564   6.439315  -3.576817
# 565   3.793382  -3.584048
# 566   1.256179  -1.902297
# 567  10.374794   1.672010
# 568  -5.475243  -0.670637
#
# [569 rows x 2 columns]

# %%
"""
Berfungsi untuk mengetahui seberapa bagus komponen PCA yang kita buat.
"""
sns.lmplot( x="PC1", y="PC2",
  data=dfPCFull, 
  fit_reg=False, 
  hue='Y', # color by cluster
  legend=True,
  scatter_kws={"s": 80})

# %% [markdown]
# # 4. Determine number of components
# Banyaknya komponen dapat ditentukan berdasarkan
# 1. **Cumulative Variance Explained** : 80 % dianggap sudah mewakili
# 2. **Eigen Value** : Nilai eigen lebih dari 1

# %%
def getExplainedVariance(df,k):
    X = df.drop('Y',axis=1)
    Y = pd.DataFrame(df['Y'])
    x = StandardScaler().fit_transform(X) # scalling
    
    pca_model = PCA(n_components=k).fit(x) # set number of components
    vr = pd.DataFrame(pca_model.explained_variance_ratio_ *100) # get variance explained ratio
    ev = pd.DataFrame(pca_model.explained_variance_ ) # get eigenvalue
    cumsum_vr = pd.DataFrame(np.cumsum(vr))
    
    expl = pd.concat([vr,cumsum_vr,ev],axis=1)
    expl.reset_index(inplace=True)
    expl.columns = ['k','Variance Explained','Cumulative Variance Explained','Eigen Value']
    
    return expl

# %%
"""
Berdasarkan eigenvalue, kita bisa memilih sampai 6 buah komponen. Sedangkan berdasarkan
variance comulatif, kita bisa memilih minimal 2 buah komponen.
"""
df_ExplainedVar = getExplainedVariance(breast_data,10)
df_ExplainedVar
# Out:
#    k  Variance Explained  Cumulative Variance Explained  Eigen Value
# 0  0           44.272026                      44.272026    13.304991
# 1  1           18.971182                      63.243208     5.701375
# 2  2            9.393163                      72.636371     2.822910
# 3  3            6.602135                      79.238506     1.984128
# 4  4            5.495768                      84.734274     1.651633
# 5  5            4.024522                      88.758796     1.209482
# 6  6            2.250734                      91.009530     0.676409
# 7  7            1.588724                      92.598254     0.477456
# 8  8            1.389649                      93.987903     0.417629
# 9  9            1.168978                      95.156881     0.351311

# %% [markdown]
# ### Scree Plot

# %%
"""
Berdasarkan komulatif keragaman, banyaknya komponen yang mewakili data adalah 3 (sekitar 80%).
"""
sns.lineplot(x = 'k',y = 'Cumulative Variance Explained',data=df_ExplainedVar)
plt.show()

# %%
"""
Berdasarkan plot eigen value, kita bisa memilih sampai 6 buah komponen.
"""
sns.lineplot(x = 'k',y = 'Eigen Value',data=df_ExplainedVar)
plt.show()

# %% [markdown]
# ## Refference
# 1. https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.PCA.html
# 2. https://www.datacamp.com/community/tutorials/principal-component-analysis-in-python
