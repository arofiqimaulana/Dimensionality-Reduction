# %%
from sklearn.datasets import load_breast_cancer
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Import Data

# %%
# Load Data
breast = load_breast_cancer()

# %%
# Convert to dataframe
X = pd.DataFrame(breast.data)
Y = pd.DataFrame(breast.target)
kolom = list(breast.feature_names) + ['Y']

# %%
# Set column names
breast_data = pd.concat([X,Y],axis=1)
breast_data.columns = kolom

# %%
breast_data
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0             0.27760         0.30010              0.14710         0.2419
# 1             0.07864         0.08690              0.07017         0.1812
# 2             0.15990         0.19740              0.12790         0.2069
# 3             0.28390         0.24140              0.10520         0.2597
# 4             0.13280         0.19800              0.10430         0.1809
# ..                ...             ...                  ...            ...
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                   0.07871  ...          17.33           184.60      2019.0
# 1                   0.05667  ...          23.41           158.80      1956.0
# 2                   0.05999  ...          25.53           152.50      1709.0
# 3                   0.09744  ...          26.50            98.87       567.7
# 4                   0.05883  ...          16.67           152.20      1575.0
# ..                      ...  ...            ...              ...         ...
# 564                 0.05623  ...          26.40           166.10      2027.0
# 565                 0.05533  ...          38.25           155.00      1731.0
# 566                 0.05648  ...          34.12           126.70      1124.0
# 567                 0.07016  ...          39.42           184.60      1821.0
# 568                 0.05884  ...          30.37            59.16       268.6
#
#      worst smoothness  worst compactness  worst concavity  \
# 0             0.16220            0.66560           0.7119
# 1             0.12380            0.18660           0.2416
# 2             0.14440            0.42450           0.4504
# 3             0.20980            0.86630           0.6869
# 4             0.13740            0.20500           0.4000
# ..                ...                ...              ...
# 564           0.14100            0.21130           0.4107
# 565           0.11660            0.19220           0.3215
# 566           0.11390            0.30940           0.3403
# 567           0.16500            0.86810           0.9387
# 568           0.08996            0.06444           0.0000
#
#      worst concave points  worst symmetry  worst fractal dimension  Y
# 0                  0.2654          0.4601                  0.11890  0
# 1                  0.1860          0.2750                  0.08902  0
# 2                  0.2430          0.3613                  0.08758  0
# 3                  0.2575          0.6638                  0.17300  0
# 4                  0.1625          0.2364                  0.07678  0
# ..                    ...             ...                      ... ..
# 564                0.2216          0.2060                  0.07115  0
# 565                0.1628          0.2572                  0.06637  0
# 566                0.1418          0.2218                  0.07820  0
# 567                0.2650          0.4087                  0.12400  0
# 568                0.0000          0.2871                  0.07039  1
#
# [569 rows x 31 columns]

# %% [markdown]
# # 2. Non-Negative Matrix Factorization (NMF)
# Goal utama dari ini adalah menemukan matriks W yang memenuhi persamaan **V = WH** dimana
# - **V** merupakan matriks data awal yang berukuran m x n
# - **W** merupakan matriks yang berukuran m x k
# - **H** merupakan matriks yang berukuran k x n
#
# dimana m adalah banyaknya observasi, n adalah banyaknya variabel dan k adalah banyaknya komponen yang terbentuk

# %%
from sklearn.decomposition import NMF

# %%
model = NMF(n_components=2, init='random', random_state=0, max_iter=50000)

# %%
W = model.fit_transform(X)
H = model.components_

# %%
df_NMF = pd.DataFrame(W)
df_NMF.columns = ['NM1','NM2']
df_NMF
# Out:
#            NM1        NM2
# 0    19.501659   7.146940
# 1    18.203181  20.847962
# 2    15.818966  20.153354
# 3     5.202298   6.942521
# 4    14.229749  26.056207
# ..         ...        ...
# 564  18.724250  25.610713
# 565  15.943794  22.101390
# 566  10.227441  16.356143
# 567  16.856303  21.068639
# 568   2.439424   3.491590
#
# [569 rows x 2 columns]

# %%
"""
Dapat kita lihat bahwa perkalian dua matriks antara W dan H akan menghasilkan hasil yang setara dengan
data raw X.
"""
pd.DataFrame(np.matmul(W,H)).head()
# Out:
#           0          1           2            3         4         5   \
# 0  13.321425  13.337769   89.616624  1016.228911  0.055387  0.118853
# 1  23.697475  29.026279  155.794374  1313.887044  0.139559  0.179953
# 2  22.211169  27.605123  145.749813  1194.262521  0.133898  0.166294
# 3   7.554562   9.446430   49.533922   400.862607  0.045985  0.056221
# 4  26.277900  34.101224  171.449675  1278.566313  0.169576  0.188179
#
#          6         7         8         9   ...         20         21  \
# 0  0.166753  0.095415  0.101892  0.029933  ...  20.152346  20.072553
# 1  0.189231  0.106238  0.261538  0.087315  ...  28.769733  39.093677
# 2  0.169268  0.094790  0.251184  0.084406  ...  26.431823  36.896928
# 3  0.056412  0.031554  0.086301  0.029077  ...   8.913634  12.586133
# 4  0.171041  0.094872  0.319015  0.109128  ...  29.345447  44.573851
#
#            22           23        24        25        26        27        28  \
# 0  135.974696  2018.536645  0.089639  0.347851  0.455878  0.187284  0.199711
# 1  191.407631  1957.185345  0.194246  0.449394  0.527065  0.222514  0.428264
# 2  175.598692  1711.328153  0.184685  0.408443  0.472613  0.200220  0.406904
# 3   59.180113   564.417284  0.063192  0.137092  0.157681  0.066904  0.139187
# 4  194.017520  1580.251261  0.227963  0.437143  0.481913  0.206778  0.501265
#
#          29
# 0  0.053826
# 1  0.121381
# 2  0.115700
# 3  0.039629
# 4  0.143856
#
# [5 rows x 30 columns]

# %%
X.head()
# Out:
#       0      1       2       3        4        5       6        7       8   \
# 0  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.3001  0.14710  0.2419
# 1  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.0869  0.07017  0.1812
# 2  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.1974  0.12790  0.2069
# 3  11.42  20.38   77.58   386.1  0.14250  0.28390  0.2414  0.10520  0.2597
# 4  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.1980  0.10430  0.1809
#
#         9   ...     20     21      22      23      24      25      26      27  \
# 0  0.07871  ...  25.38  17.33  184.60  2019.0  0.1622  0.6656  0.7119  0.2654
# 1  0.05667  ...  24.99  23.41  158.80  1956.0  0.1238  0.1866  0.2416  0.1860
# 2  0.05999  ...  23.57  25.53  152.50  1709.0  0.1444  0.4245  0.4504  0.2430
# 3  0.09744  ...  14.91  26.50   98.87   567.7  0.2098  0.8663  0.6869  0.2575
# 4  0.05883  ...  22.54  16.67  152.20  1575.0  0.1374  0.2050  0.4000  0.1625
#
#        28       29
# 0  0.4601  0.11890
# 1  0.2750  0.08902
# 2  0.3613  0.08758
# 3  0.6638  0.17300
# 4  0.2364  0.07678
#
# [5 rows x 30 columns]

# %% [markdown]
# # Refference
# 1. https://papers.nips.cc/paper/2000/file/f9d1152547c0bde01830b7e8bd60024c-Paper.pdf
# 2. https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.NMF.html
